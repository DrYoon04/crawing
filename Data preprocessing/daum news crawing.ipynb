# %% [markdown]
# ### 라이브러리 불러오기

# %%
import requests
from bs4 import BeautifulSoup
import re

url = "https://news.daum.net/"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"}

html = requests.get(url, headers=headers)
soup = BeautifulSoup(html.content, 'html.parser')
news_block = soup.find(class_="box_g box_news_issue")
news_main = news_block.find_all(class_="tit_g")

news_block_len = len(news_main)
print(f'가져온 뉴스의 해드라인은 {news_block_len}개 입니다')
news_content_link = []
news_content_headline = []

for i in range(news_block_len):
    link_element = news_main[i].find('a', class_='link_txt')
    if link_element and 'href' in link_element.attrs:
        news_content_link.append(link_element['href'])
    else:
        news_content_link.append("N/A")  
        
    # 기사 제목을 추출합니다.
    headline_element = news_main[i].find('a')
    if headline_element:
        news_content_headline.append(headline_element.text)
    else:
        news_content_headline.append("N/A")  # 기사 제목을 찾을 수 없는 경우 처리

cleaned_data = []
for item in news_content_headline:
    # 공백 제거 및 제목 부분 추출
    cleaned_item = re.sub(r'\n\s*', '', item.strip())
    cleaned_data.append(cleaned_item)

# 가져온 내용 출력
for i in range(news_block_len):
    print(f"링크: {news_content_link[i]}")
    print(f"기사 제목: {cleaned_data[i]}")
# Out:
# 가져온 게임의 판수는 20판 입니다
# 링크: https://v.daum.net/v/20230914001024988
# 기사 제목: 크렘린 "金, 한반도 정세 등 설명…푸틴 흥미로워 해"
# 링크: https://v.daum.net/v/20230914011820344
# 기사 제목: 유엔 사무총장 "북러 협력, 대북제재 벗어나지 말아야"
# 링크: https://v.daum.net/v/20230913194330003
# 기사 제목: 부산대·교대 통합 의견수렴…부산대생 반발도 변수로
# 링크: https://v.daum.net/v/20230913204835003
# 기사 제목: 한달 남은 엑스포 유치 올인 위해 부산시 국감 면제 노력 분주
# 링크: https://v.daum.net/v/20230913194325999
# 기사 제목: 가덕신공항 부지 토지·어업 보상 조사 시작
# 링크: https://v.daum.net/v/20230914001245005
# 기사 제목: 방문규 청문경과보고서 채택 불발…여 "정치적 결론" 야 "답변 부실"
# 링크: https://v.daum.net/v/20230913235839722
# 기사 제목: 경남 하동 '호우주의보' 발효…금남면 누적 강수량 32.5㎜
# 링크: https://v.daum.net/v/20230914005053250
# 기사 제목: 러-인도, 북해항로·동부해상로 활용 해상 운송협력 확대
# 링크: https://v.daum.net/v/20230914005452268
# 기사 제목: 블링컨 "캠프 데이비드 회의로 한미일 관계 넥스트 레벨 도달"
# 링크: https://v.daum.net/v/20230913232737501
# 기사 제목: 코레일, 파업 대비 전국 긴급 비상대책회의 개최
# 링크: https://v.daum.net/v/20230913233709565
# 기사 제목: 러 외무, 유엔 대북 제재 관련 "북·중·러 모두 속았다"
# 링크: https://v.daum.net/v/20230914000100779
# 기사 제목: 정부청사에 배식된 국내산 수산물···'가격 대비 아쉬운 품질' [TF사진관]
# 링크: https://v.daum.net/v/20230914000124796
# 기사 제목: '유령직원' 의혹에, '부실' 논란까지…태영건설 청년주택 '엉망진창'?
# 링크: https://v.daum.net/v/20230914003105155
# 기사 제목: [날씨] 전국 흐리고 오전까지 가을비
# 링크: https://v.daum.net/v/20230914004144221
# 기사 제목: 유엔 보고관 "위안부 합의 개정하고 국보법 폐지수순 밟아야"
# 링크: https://v.daum.net/v/20230914003000137
# 기사 제목: “이건 여야가 한 목소리”…소멸 막는 지방투자촉진법 [김혜진의 알쓸경법]
# 링크: https://v.daum.net/v/20230913233538550
# 기사 제목: 중국, 동중국해에 100m 높이 해양 전망대… 분쟁국 감시용?
# 링크: https://v.daum.net/v/20230913203219788
# 기사 제목: 실손보험 청구 간소화, 또 제동… 박주민 “보험사 이익 늘어날 가능성”
# 링크: https://v.daum.net/v/20230914000015747
# 기사 제목: 박테리아 닮은 인간 면역 단백질… “단백질 진화 돌아보는 타임머신 찾았다”
# 링크: https://v.daum.net/v/20230914000405856
# 기사 제목: 정치혼란이 부른 최악 참사… 리비아 대홍수는 人災
