# %% [markdown]
# ### 라이브러리 불러오기

# %%
import requests
from bs4 import BeautifulSoup
import re

url = "https://news.daum.net/"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"}

html = requests.get(url, headers=headers)
soup = BeautifulSoup(html.content, 'html.parser')
news_block = soup.find(class_="box_g box_news_issue")
news_main = news_block.find_all(class_="tit_g")

news_block_len = len(news_main)

news_content_link = []
news_content_headline = []

for i in range(news_block_len):
    link_element = news_main[i].find('a', class_='link_txt')
    if link_element and 'href' in link_element.attrs:
        news_content_link.append(link_element['href'])
    else:
        news_content_link.append("N/A")  
        
    # 기사 제목을 추출합니다.
    headline_element = news_main[i].find('a')
    if headline_element:
        news_content_headline.append(headline_element.text)
    else:
        news_content_headline.append("N/A")  # 기사 제목을 찾을 수 없는 경우 처리

cleaned_data = []
for item in news_content_headline:
    # 공백 제거 및 제목 부분 추출
    cleaned_item = re.sub(r'\n\s*', '', item.strip())
    cleaned_data.append(cleaned_item)

# 가져온 내용 출력
print(f'가져온 뉴스의 해드라인은 {news_block_len}개 입니다')
for i in range(news_block_len):
    print(f"{i+1} 기사 제목: {cleaned_data[i]}")
    print(f"링크: {news_content_link[i]}")
# Out:
# 가져온 뉴스의 해드라인은 20개 입니다
# 1 기사 제목: 스위스 의회 "푸아그라 수입, 신고요건 갖출 땐 허용"
# 링크: https://v.daum.net/v/20230915004210376
# 2 기사 제목: 국가채무 1100조원 돌파 ‘초읽기’
# 링크: https://v.daum.net/v/20230914202400430
# 3 기사 제목: '수서행 KTX'는 왜 핵심 쟁점이 되었나
# 링크: https://v.daum.net/v/20230914201506224
# 4 기사 제목: '기후변화 방지 협조 약속' 엑손모빌, 물밑에선 여론뒤집기 시도
# 링크: https://v.daum.net/v/20230915003022338
# 5 기사 제목: 8월 호주 실업률 3.7% 보합..."생산성 논란 속 취업자 대폭 ↑"
# 링크: https://v.daum.net/v/20230914235947951
# 6 기사 제목: 미 재무부, 러시아 관련 신규 제재…"군사공급망 겨냥"
# 링크: https://v.daum.net/v/20230915001606264
# 7 기사 제목: 디샌티스, 지지율 부진에 후원자와 여러 차례 호화여행 의혹까지
# 링크: https://v.daum.net/v/20230915001438252
# 8 기사 제목: 동원 불만에 동력 상실… 촛불문화제 멈춘 민주
# 링크: https://v.daum.net/v/20230914181522682
# 9 기사 제목: 中 인민은행, 지준율 0.25%p인하...돈 풀어 경기부양
# 링크: https://v.daum.net/v/20230914202400431
# 10 기사 제목: 늦더위 여전한데 핫팩·붕어빵 등장! 겨울나기 돌입한 편의점 업계
# 링크: https://v.daum.net/v/20230915000051993
# 11 기사 제목: [단독] "밤 기술 좋다"…도로공사서비스의  '이상한 성희롱·성폭행 징계'
# 링크: https://v.daum.net/v/20230915000036984
# 12 기사 제목: [경제카메라]“일하다 관광”…능률 올리고 경제 살리는 ‘워케이션’
# 링크: https://v.daum.net/v/20230914200308000
# 13 기사 제목: 이재명 단식 중단 요청했지만…“찾을 계획 없다” 선 그은 국힘
# 링크: https://v.daum.net/v/20230914204508886
# 14 기사 제목: 조응천 "이재명 불체포 포기 명확히 말해…방탄 굴레 벗어나려면 지켜야" [정치와이드]
# 링크: https://v.daum.net/v/20230914182105853
# 15 기사 제목: "기대가 너무 높았나"…네오위즈 ‘P의 거짓’ 불안한 출발
# 링크: https://v.daum.net/v/20230914233823806
# 16 기사 제목: 트럼프, 바이든 나이 공격 자제…"늙은게 아니라 무능"
# 링크: https://v.daum.net/v/20230914234334857
# 17 기사 제목: "140kg 무게 감당될까"…北 경호원들, 생사 걸린 듯 김정은 의자 점검
# 링크: https://v.daum.net/v/20230914182151863
# 18 기사 제목: 화석 발전소를 역사의 화석으로…9월15일 기후파업
# 링크: https://v.daum.net/v/20230914232802696
# 19 기사 제목: [올댓차이나] 인민은행, 대형은행에 달러 매수 간격 조정 지시
# 링크: https://v.daum.net/v/20230914230935567
# 20 기사 제목: [올댓차이나] 무디스, 中 부동산 부문 신용전망 '부정적'으로 변경
# 링크: https://v.daum.net/v/20230914233144752
